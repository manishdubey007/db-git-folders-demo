# %% [markdown]
# ### Configure Access to Cloud Storage via unity catalog

# %%
# %fs ls 'abfss://demo@databrickscourseextmandl.dfs.core.windows.net/'

# %% [markdown]
# ### Create external location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_demo
    URL 'abfss://demo@databrickscourseextmandl.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL dsa_course_ext_sc)
    COMMENT 'External Location for Demo Purposes;'
