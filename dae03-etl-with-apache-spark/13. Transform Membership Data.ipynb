# %% [markdown]
# #### Transform Membership Data
# - Extract customer_id from the file path
# - Write transformed data in silver schema

# %% [markdown]
# ####1. Extract customer_id from the file path
# - https://docs.databricks.com/aws/en/sql/language-manual/functions/regexp_extract
# - https://regexr.com/
# - https://docs.oracle.com/javase/8/docs/api/java/util/regex/Pattern.html

# %%
# %sql
SELECT 
    CAST(regexp_extract(path,'.*/([0-9]+)\\.png$',1) AS bigint) AS customer_id,
    content AS membership_card
FROM gizmobox.bronze.v_memberships

# %% [markdown]
# #### 2. Write transformed data in silver schema

# %%
# %sql
CREATE TABLE gizmobox.silver.memberships
AS
SELECT 
    CAST(regexp_extract(path,'.*/([0-9]+)\\.png$',1) AS bigint) AS customer_id,
    content AS membership_card
FROM gizmobox.bronze.v_memberships;

# %%
# %sql
SELECT * FROM gizmobox.silver.memberships
